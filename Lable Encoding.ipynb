# %% [markdown]
# ### import pandas as pd
# df = pd.DataFrame({"name":["appwars","python","ml","sql","aws"]})

# %%
df
# Out:
#       name
# 0  appwars
# 1   python
# 2       ml
# 3      sql
# 4      aws

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder ()

# %%
le.fit_transform(df["name"])
# Out:
# array([0, 3, 2, 4, 1])

# %%
df["en_name"] = le.fit_transform(df["name"])

# %%
df
# Out:
#       name  en_name
# 0  appwars        0
# 1   python        3
# 2       ml        2
# 3      sql        4
# 4      aws        1
